# %% [markdown]
# Google Drive 연동하는 방법 기억나시나요?

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/MyDrive/Colab Notebooks/Lecture/data
# !ls
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Lecture/data
# naive_baeys_data.csv

# %% [markdown]
# 이번시간에는 Naive Bayes 실습을 진행해보겠습니다.

# %%
import numpy as np
import math
import pandas as pd

# %% [markdown]
# 1. 우선, 데이터를 불러와야 합니다.
#
# naive_baeys_data.csv 파일을 불러와보세요.

# %%
df = ?????.?????('naive_baeys_data.csv')

# %% [markdown]
# 2. 데이터가 어떻게 생겼는지 확인해보세요. (head 기능 있었죠?!)

# %%
df.?????
# Out:
#     Outlook Temp Humidity  Windy Play Golf
# 0     Rainy  Hot     High  False        No
# 1     Rainy  Hot     High   True        No
# 2  Overcast  Hot     High  False       Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Outlook    14 non-null     object
#  1   Temp       14 non-null     object
#  2   Humidity   14 non-null     object
#  3   Windy      14 non-null     bool
#  4   Play Golf  14 non-null     object
# dtypes: bool(1), object(4)
# memory usage: 590.0+ bytes

# %%
df = df.dropna()

# %% [markdown]
# 우리가 구하고 싶은 것은, (Rainy, Cool, High, True)일 때, Play Golf가 True일 확률을 구하는 것입니다. (MathAI_lecture13_20211108 17p)
#
# 3. 우선, p(yes)를 구해보세요.

# %%
num_data = len(df)
num_yes = len(?????)
p_yes = num_yes/num_data
print(p_yes)
# Out:
# 0.6428571428571429

# %% [markdown]
# 4. 이번에는 p(Rainy|Yes)를 구해보겠습니다.

# %%
num_rainy_yes = len(?????)
p_rainy_yes = num_rainy_yes / num_yes
print(p_rainy_yes)
# Out:
# 0.2222222222222222

# %% [markdown]
# 5. 이번에는 마찬가지로, p(cool|yes), p(high|yes), p(true|yes) 를 구해보세요.

# %%
num_cool_yes = len(?????)
p_cool_yes = num_cool_yes / num_yes 

num_high_yes = len(?????)
p_high_yes = num_high_yes / num_yes 

num_true_yes = len(?????)
p_true_yes = num_true_yes / num_yes
print(p_cool_yes, p_high_yes, p_true_yes)
# Out:
# 0.3333333333333333 0.3333333333333333 0.3333333333333333

# %% [markdown]
# 6. 마지막으로, p(Yes|Rainy, Cool, High, True)를 구해보세요.

# %%
prob = ?????
print(prob)
# Out:
# 0.005291005291005291
