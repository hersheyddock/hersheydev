# %% [markdown]
# ## 91-100. 파이썬 딕셔너리

# %% [markdown]
# ### Q91.
# 아래의 표에서, 아이스크림 이름을 키값으로, (가격, 재고) 리스트를 딕셔너리의 값으로 저장하라. 딕셔너리의 이름은 inventory로 한다.
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-10-20%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.27.20.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-10-20%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.27.20.png)

# %%
inventory = {"메로나":[300,20], 
             "비비빅":[400,3], 
             "죠스바":[250,100]} # 리스트로 담아야 인덱싱 가능

# %%
type(inventory)
# Out:
# dict

# %% [markdown]
# ### Q92. 딕셔너리 인덱싱
# inventory 딕셔너리에서 메로나의 가격을 화면에 출력하라.

# %%
print("현재 메로나의 가격은", inventory["메로나"][0], "원 입니다")
# Out:
# 현재 메로나의 가격은 300 원 입니다

# %% [markdown]
# ### Q93. 딕셔너리 인덱싱
# inventory 딕셔너리에서 메로나의 재고를 화면에 출력하라.

# %%
print("현재 메로나의 재고는", inventory["메로나"][1], "개 입니다")
# Out:
# 현재 메로나의 재고는 20 개 입니다

# %% [markdown]
# ### Q94. 딕셔너리 추가
# inventory 딕셔너리에 아래 데이터를 추가하라.
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-10-20%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.36.37.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-10-20%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.36.37.png)

# %%
inventory["월드콘"]=[500, 7]

# dict는 추가할 때가 훨씬 직관적이네

# %%
inventory
# Out:
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100], '월드콘': [500, 7]}

# %% [markdown]
# ### Q95. 딕셔너리 keys() 메서드
# 다음의 딕셔너리로부터 key 값으로만 구성된 리스트를 생성하라.

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}

# %%
icecream_keys = list(icecream.keys())

# %%
icecream_keys
# Out:
# ['탱크보이', '폴라포', '빵빠레', '월드콘', '메로나']

# %% [markdown]
# ### Q96. 딕셔너리 values() 메서드
# 다음의 딕셔너리로부터 values 값으로만 구성된 리스트를 생성하라.

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}

# %%
icecream_values = list(icecream.values())

# %%
icecream_values
# Out:
# [1200, 1200, 1800, 1500, 1000]

# %% [markdown]
# ### Q97. 딕셔너리 values() 메서드
# icecream 딕셔너리에서 아이스크림 판매 금액의 총합을 출력하라.

# %%
icecream
# Out:
# {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}

# %%
sum(icecream_values)
# Out:
# 6700

# %%
import numpy as np
np.sum(icecream_values)

if sum(icecream_values) == np.sum(icecream_values):
    print(f"sum 메서드와 np.sum 메서드의 합이 {sum(icecream_values)}원으로 같습니다")
# Out:
# sum 메서드와 np.sum 메서드의 합이 6700원으로 같습니다

# %% [markdown]
# ### Q98. 딕셔너리 update 메서드
# 아래의 new_product 딕셔너리를 다음 icecream 딕셔너리에 추가하라.

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
new_product = {'팥빙수':2700, '아맛나':1000}

# %%
icecream.update(new_product)
# list에서의 append와 동일한 기능. 근데 이제 key:value 쌍을 곁들인..

# %%
icecream
# Out:
# {'탱크보이': 1200,
#  '폴라포': 1200,
#  '빵빠레': 1800,
#  '월드콘': 1500,
#  '메로나': 1000,
#  '팥빙수': 2700,
#  '아맛나': 1000}

# %%
len(icecream)
# Out:
# 7

# %% [markdown]
# ### Q99. zip과 dict
# 아래 두 개의 튜플을 하나의 딕셔너리로 변환하라. keys를 키로, vals를 값으로 result 이름의 딕셔너리로 저장한다.

# %%
keys = ("apple", "pear", "peach")
vals = (300, 250, 400)

# %%
result = dict(zip(keys, vals))
result
# Out:
# {'apple': 300, 'pear': 250, 'peach': 400}

# %%
# 리스트로 zip해줬을 경우
print("리스트 :", list(zip(keys, vals)))

# 딕셔너리로 zip해줬을 경우
print("딕셔너리 :", dict(zip(keys, vals)))
# Out:
# 리스트 : [('apple', 300), ('pear', 250), ('peach', 400)]
# 딕셔너리 : {'apple': 300, 'pear': 250, 'peach': 400}

# %% [markdown]
# ### Q100. zip과 dict
# date와 close_price 두 개의 리스트를 close_table 이름의 딕셔너리로 생성하라.
#
# 실행 예시:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}

# %%
date = ['09/05', '09/06', '09/07', '09/08', '09/09']
close_price = [10500, 10300, 10100, 10800, 11000]

# %%
close_table = dict(zip(date, close_price))
print(close_table)
# Out:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}
